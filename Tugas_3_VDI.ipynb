# %% [markdown]
# Nama: Irhamna Mahdi
#
# NIM: 122450049
#
# Kelas: RA

# %% [markdown]
# Tujuan: Membuat grafik perubahan harga dari tahun 2019 hingga 2024 serta perubahan volumenya
#
# User: Data tersebut ditujukan untuk orang yang ingin mengetahui perkembangan saham Apple (AAPL)
#
# Fungsi:
# *   Date = Tanggal tercatat saham
# *   Open = Harga awal dibuka di hari tersebut
# *   High = Harga tertinggi di hari tersebut
# *   Low = Harga terendah di hari tersebut
# *   Close = Harga akhir ditutup di hari tersebut
# *   Volume = Jumlah saham yang beredar

# %%
import pandas as pd
import plotly.graph_objects as go
from datetime import datetime

# %%
data = pd.read_csv("/content/aapl_us_d.csv")
data
# Out:
#            Date      Open      High       Low     Close       Volume
# 0      1/2/2019   37.3770   38.3281   37.2125   38.1048  153504636.2
# 1      1/3/2019   34.7431   35.1588   34.2635   34.3094  378427243.0
# 2      1/4/2019   34.8746   35.8446   34.6991   35.7729  242886638.3
# 3      1/7/2019   35.8786   35.9104   35.2046   35.6911  227016761.0
# 4      1/8/2019   36.0899   36.6342   35.8367   36.3711  170022160.9
# ...         ...       ...       ...       ...       ...          ...
# 1425  8/30/2024  230.1900  230.4000  227.4800  229.0000   52990770.0
# 1426   9/3/2024  228.5500  229.0000  221.1700  222.7700   50190574.0
# 1427   9/4/2024  221.6600  221.7800  217.4800  220.8500   43840196.0
# 1428   9/5/2024  221.6250  225.4800  221.5200  222.3800   36615398.0
# 1429   9/6/2024  223.9500  225.2400  219.7700  220.8600   48370990.0
#
# [1430 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
Viz = go.Figure(data=[go.Candlestick(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'])])

Viz.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
VolViz = go.Figure([go.Scatter(x=data['Date'], y=data['Volume'])])
VolViz.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
